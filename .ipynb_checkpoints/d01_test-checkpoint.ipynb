# %%
import gc
import warnings
warnings.filterwarnings('ignore')
import scipy as sp
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
import itertools
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('code')

# %%
from utils import *

# %%
from optimizegrouping import OptmizeGrouping

# %%
raw_data = pd.read_csv('data/amex_sample_data.csv')

# %%
raw_data.head()
# Out:
#                                          customer_ID       P_2      D_39       B_1       B_2       R_1       S_3      D_41       B_3  D_42      D_43      D_44       B_4      D_45       B_5       R_2      D_46      D_47      D_48  D_49       B_6       B_7       B_8      D_50      D_51       B_9       R_3      D_52       P_3      B_10      D_53       S_5      B_11       S_6      D_54       R_4       S_7      B_12       S_8      D_55      D_56      B_13       R_5      D_58       S_9      B_14      D_59      D_60      D_61      B_15      S_11      D_62      D_65      B_16      B_17      B_18      B_19      B_20      S_12       R_6      S_13      B_21      D_69      B_22      D_70      D_71      D_72      S_15      B_23  D_73       P_4      D_74      D_75  D_76      B_24       R_7      D_77      B_25      B_26      D_78      D_79       R_8  R_9      S_16      D_80      R_10      R_11      B_27      D_81      D_82      S_17      R_12      B_28      R_13      D_83      R_14      R_15  \
# ...

# %%
raw_data.shape
# Out:
# (8294, 190)

# %%
raw_data[raw_data.B_2.isnull()]
# Out:
#                                             customer_ID  P_2      D_39      B_1  B_2      R_1       S_3  D_41  B_3  D_42  D_43  D_44       B_4  D_45       B_5       R_2  D_46      D_47  D_48  D_49  B_6       B_7      B_8  D_50      D_51       B_9       R_3  D_52  P_3      B_10  D_53       S_5      B_11       S_6  D_54       R_4       S_7      B_12       S_8  D_55  D_56  B_13       R_5      D_58  S_9      B_14  D_59      D_60      D_61      B_15      S_11      D_62      D_65  B_16  B_17      B_18  B_19  B_20      S_12       R_6      S_13      B_21  D_69  B_22  D_70      D_71  D_72      S_15      B_23  D_73       P_4      D_74      D_75  D_76      B_24       R_7      D_77     B_25  B_26  D_78  D_79      R_8  R_9      S_16      D_80      R_10      R_11  B_27  D_81  D_82      S_17      R_12     B_28      R_13  D_83      R_14      R_15  D_84      R_16  B_29      S_18      D_86  D_87     R_17      R_18  D_88  B_31      S_19     R_19      B_32      S_20      R_20      R_21  B_33  D_89  \
# ...

# %%
cc = OptmizeGrouping(data=raw_data, xname='D_41', yname='target')
cc.coarsebin_interval()
# Out:
# ...
#                                            D_41_bins  Good  Bad  Total     %Good      %Bad    %Total  Bad_Rate       WOE        IV      Odds
# 0                        1. ( -inf, 0.001152588048 ]   348   67    415  0.060438  0.031589  0.052672  0.161446  0.648807  0.018717  5.194030
# 1            2. (  0.001152588048 , 0.002354993952 ]   677  153    830  0.117576  0.072136  0.105343  0.184337  0.488531  0.022199  4.424837
# 2     3. (  0.002354993952 , 0.0035396404080000016 ]   687  142    829  0.119312  0.066950  0.105216  0.171291  0.577805  0.030255  4.838028
# 3  4. (  0.0035396404080000016 , 0.16841496520000...  3669  892   4561  0.637200  0.420556  0.578881  0.195571  0.415506  0.090017  4.113229
# 4  5. (  0.16841496520000077 , 0.34285927679999983 ]   215  200    415  0.037339  0.094295  0.052672  0.481928 -0.926382  0.052763  1.075000
# ...

# %%
feats = ["P_2", "D_39", "B_1", "B_2", "R_1", "S_3", "D_41"]

# %%
from IPython.display import display
for var in feats:
    print(var)
    cc = OptmizeGrouping(data=raw_data, xname=var, yname='target', mingroupsize=0.03)
    res = cc.coarsebin_interval()
    display(res)
# Out:
# P_2
#                    P_2_bins  Good   Bad  Total     %Good      %Bad    %Total  Bad_Rate       WOE        IV        Odds
# 0                      Null    37     9     46  0.006104  0.004942  0.005835  0.195652  0.211039  0.000245    4.111111
# 1         1. ( -inf, True ]  5615  1810   7425  0.926262  0.993959  0.941900  0.243771 -0.070539  0.004775    3.102210
# 2  2. (  True , 1.0098933 ]   410     2    412  0.067634  0.001098  0.052264  0.004854  4.120356  0.274153  205.000000
# D_39
#                    D_39_bins  Good   Bad  Total    %Good      %Bad    %Total  Bad_Rate       WOE        IV      Odds
# 0  1. ( -inf, 0.9143725813 ]  5719  1746   7465  0.99409  0.820874  0.947335  0.233891  0.191458  0.033163  3.275487
# 1   3. (  True , 3.3825579 ]    34   381    415  0.00591  0.179126  0.052665  0.918072 -3.411448  0.590916  0.089239
# B_1
#                    B_1_bins  Good   Bad  Total     %Good      %Bad    %Total  Bad_Rate       WOE        IV      Odds
# ...

# %%
xname = 'D_63'
target = 'target'

# %%
dataset=raw_data[[xname,target]]

# %%
crosstab_dt = pd.crosstab(raw_data['D_63'], raw_data['target'], margins=True)

# %%
crosstab_dt = pd.crosstab(raw_data['D_63'], raw_data['target'], margins=True)
crosstab_dt.columns = ['Good', "Bad", 'All']
crosstab_dt.fillna(0, inplace=True)
crosstab_dt.reset_index(inplace=True)

# %%
crosstab_dt
# Out:
#   D_63  Good   Bad   All
# 0   CL   419   219   638
# 1   CO  4483  1702  6185
# 2   CR  1123   247  1370
# 3   XL    13     6    19
# 4   XM    15     8    23
# 5   XZ    43    16    59
# 6  All  6096  2198  8294

# %%
crosstab_dt['%All'] = crosstab_dt.All / crosstab_dt.All.sum()
crosstab_dt['bad_rate'] = crosstab_dt.Bad / crosstab_dt.All

# %%
crosstab_dt.sort_values('%All', inplace=True)
crosstab_dt.reset_index(inplace=True, drop=True)
# crosstab_dt['group'] = ['seg_' + str(i) for i in range(len(crosstab_dt))]

# %%
crosstab_dt
# Out:
#   D_63  Good   Bad   All      %All  bad_rate
# 0   XL    13     6    19  0.001145  0.315789
# 1   XM    15     8    23  0.001387  0.347826
# 2   XZ    43    16    59  0.003557  0.271186
# 3   CL   419   219   638  0.038462  0.343260
# 4   CR  1123   247  1370  0.082590  0.180292
# 5   CO  4483  1702  6185  0.372860  0.275182
# 6  All  6096  2198  8294  0.500000  0.265011

# %%
cc = OptmizeGrouping(data=raw_data, xname='D_63', yname='target')
cc.coarsebin_norminal()
# Out:
#    CutPoint  Good   Bad  Total     %Good      %Bad    %Total  Bad_Rate       WOE        IV      Odds
# 0  0.180292  1123   247   1370  0.184219  0.112375  0.165180  0.180292  0.494286  0.035512  4.546559
# 1  0.271186    43    16     59  0.007054  0.007279  0.007114  0.271186 -0.031474  0.000007  2.687500
# 2  0.275182  4483  1702   6185  0.735400  0.774340  0.745720  0.275182 -0.051597  0.002009  2.633960
# 3  0.315789    13     6     19  0.002133  0.002730  0.002291  0.315789 -0.246895  0.000147  2.166667
# 4  0.343260   419   219    638  0.068734  0.099636  0.076923  0.343260 -0.371286  0.011474  1.913242
# 5  0.347826    15     8     23  0.002461  0.003640  0.002773  0.347826 -0.391476  0.000462  1.875000

# %%
dataset = raw_data[[xname, target]]

# %%
raw_data.D_68.fillna(7, inplace=True)

# %%
dataset['weight'] = raw_data.D_68

# %%
dataset['const'] = 1

# %%
pd.crosstab(dataset['D_63'], dataset['target'], values=dataset.const, aggfunc='sum',margins=True)

# %%
crosstab_dt = pd.crosstab(dataset['D_63'], dataset['target'], values=dataset.weight, aggfunc='sum')

# %%
crosstab_dt.columns = ['Good', "Bad"]

# %%
crosstab_dt.reset_index('D_63', inplace=True)

# %%
crosstab_dt

# %%
for val in list(set(dataset[xname])):
        dataset.loc[dataset[xname] == val, 'CutPoint'] = dataset.loc[(dataset[xname] == val) & (dataset[target] == 1)]['weight'].sum()/dataset.loc[dataset[xname] == val]['weight'].sum()

# %%
dataset.head()

# %%
dataset.weight.sum()

# %%
dist_x_vals = len(set(dataset[xname]))

# %%
dist_x_vals

# %%
from eda import *

# %%
categorical_analysis_plot(df=raw_data,
                          categorical_var="S_3_woe",
                          target='target'
                         )

# %%
numerical_analysis_plot(raw_data=raw_data,
                          numerical_var="P_2",
                          target='target'
                         )
